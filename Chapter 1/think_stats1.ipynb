# %% [markdown]
# <h1 style='font-size:40px'> Exploratory Data Analysis</h1>

# %% [markdown]
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Querer provar um fato envolve muito mais do que a pura coleta de informações. Antes de tudo, a maneira como os dados são obtidos deve ser priorizada.
#         </li>
#         <li>
#             Se algo é real, precisamos ter um volume considerável de instâncias que confirmem isso. Além disso, a idoneidade das informações tem que ser garantida.
#         </li>
#         <li>
#             Discussões de fóruns na internet ou conversas com amigos não providenciam informações confiáveis. As pessoas podem passionalmente se posicionar e, muitas vezes, as provas que elas utilizam para fundamentar as suas opiniões provêm de sua própria experiência com o mundo (e nada além disso).
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px;'> Importing the Data</h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Vamos trabalhar com uma pesquisa do sexto ciclo do NSGF realizado pelo CDC. Essa tem o intuito de estudar a composição das famílias americanas, sua saúde e sexualidade.
#         </li>
#     </ul>
# </div>

# %%
import thinkstats2
from nsfg import CleanFemPreg, ReadFemPreg

df = ReadFemPreg()
df.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       1         1        NaN        NaN       NaN       NaN       6.0
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 2       2         1        NaN        NaN       NaN       NaN       5.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth  ...  laborfor_i  religion_i  metro_i  \
# 0       NaN       1.0       NaN  ...           0           0        0
# 1       NaN       1.0       NaN  ...           0           0        0
# 2       NaN       3.0       5.0  ...           0           0        0
# 3       NaN       1.0       NaN  ...           0           0        0
# 4       NaN       1.0       NaN  ...           0           0        0
#
#        basewgt  adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  \
# ...

# %% [markdown]
# <h2 style='font-size:30px'> Variables</h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Somos apresentados às principais colunas a serem usadas com o dataset apresentado.
#         </li>
#     </ul>
# </div>
# <center>
#     <img src='variables1.png'>
# </center>

# %% [markdown]
# <p style='color:red'> Variables
